# %%
# %matplotlib inline
import pickle, os, tqdm, json
import numpy as np
import matplotlib.pyplot as plt

fontsize = 30
linewidth = 5
plt.rc('font',family='Times New Roman', size=fontsize)
plot_dict = {'markersize':15, 'markeredgewidth':5, 'linewidth':linewidth}
c = [[0, 0.4470, 0.7410], [0.8500, 0.3250, 0.0980], [0.9290, 0.6940, 0.1250],[0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933], [0.635, 0.078, 0.184]]

import numpy as np
data = np.load('BERTriu-no-pt-wishlist.npy', allow_pickle=True).tolist()

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111)

for h in list(range(4)) + list(range(5, 16, 5)):
    r_list = []
    #for r in list(range(1)):
    for r in list(range(6)):
        r_list.append(np.round(data[h][r][0],4))
        print(np.round(data[h][r][0], 4), end=' ')
    print('\n', end='')
    ax.plot(r_list, marker='o', linestyle='-', **plot_dict)
    
plt.ylabel('Recall@10 for (N-10)')
plt.xlabel('Reference Items')

ax.xaxis.set_ticks(np.arange(11))
ax.xaxis.set_ticklabels(np.arange(11), fontsize=30)

ax.legend(['h={}'.format(iter) for iter in [0,2,4,6,8,10]], fontsize=30,  ncol=1, loc='lower right')
# Out:
# 0.0169 0.035 0.0422 0.0485 0.0501 0.0497
# 0.038 0.0435 0.0485 0.0511 0.0521 0.0545
# 0.0421 0.0455 0.048 0.0506 0.0547 0.0581
# 0.0522 0.055 0.0571 0.0605 0.0636 0.0636
# 0.0584 0.0605 0.0636 0.0718 0.0731 0.0726
# 0.0615 0.0635 0.0703 0.0752 0.0781 0.0771
# 0.0627 0.0727 0.0852 0.0877 0.0902 0.0877

# %%
# %matplotlib inline
import pickle, os, tqdm, json
import numpy as np
import matplotlib.pyplot as plt

fontsize = 30
linewidth = 5
import matplotlib.font_manager as font_manager
fname='/data/shaoerzhuo/Fonts/'
font_dirs = [fname, ]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
font_list = font_manager.createFontList(font_files)
font_manager.fontManager.ttflist.extend(font_list)
plt.rcParams["font.family"] = "Times New Roman"
plt.rc('font', family='Times New Roman', size=fontsize)
plot_dict = {'markersize':15, 'markeredgewidth':5, 'linewidth':linewidth}
c = [[0, 0.4470, 0.7410], [0.8500, 0.3250, 0.0980], [0.9290, 0.6940, 0.1250],[0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933], [0.635, 0.078, 0.184]]

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111)

ax.plot(range(0, 20), np.load('BERTriu-time.npy', allow_pickle=True).tolist()[0][3][1], color=c[0], marker='x', linestyle='-', **plot_dict)
ax.plot(range(3, 20), np.load('BERTriu-time.npy', allow_pickle=True).tolist()[3][3][1], color=c[1], marker='o', linestyle='-', **plot_dict)
ax.plot(range(5, 20), np.load('BERTriu-time.npy', allow_pickle=True).tolist()[5][3][1], color=c[2], marker='+', linestyle='-', **plot_dict)
ax.plot(range(10, 20), np.load('BERTriu-time.npy', allow_pickle=True).tolist()[10][3][1], color=c[3], marker='h', linestyle='-', **plot_dict)

ax.xaxis.set_ticks(np.arange(20))
#ax.xaxis.set_ticklabels(np.arange(12))
#ax.xaxis.set_ticklabels(['Fa','Sp','Su','Fa','Sp','Su','Fa','Sp','Su','Fa','Sp','Su',], fontsize=30)
ax.legend([
    'h=0', 'h=3', 'h=5', 'h=10', 
], fontsize=30,  ncol=2, loc='best')
# Out:
# /usr/local/anaconda3/envs/tf-2.2-py3/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning:
# The createFontList function was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use FontManager.addfont instead.
#   if sys.path[0] == '':

# %%
np.load('BERTriu-time.npy', allow_pickle=True).tolist()[0][3][1]
# Out:
# array([0.09043113, 0.05582923, 0.06864275, 0.07      , 0.08421053,
#        0.08629442, 0.05614035, 0.10526316, 0.08955224, 0.1048951 ,
#        0.10526316, 0.08823529, 0.10218978, 0.11764706, 0.09183673,
#        0.13207547, 0.07954545, 0.13414634, 0.19148936, 0.15789474])
